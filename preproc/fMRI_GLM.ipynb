# %%
shuffle <- FALSE
save    <- FALSE
FU      <- FALSE

use_cached <- FALSE

# %% [markdown]
# ## Read ROI Data ##

# %%
source('import_fmri.r')

roi    <- 'Left_preSMA'
fuc    <- 'BL'
subset <- 'train'

data   <- import_fmri(subset,fuc,roi)

stn_series  <- data$stn_series
sst_times   <- data$sst_times
sst_outcome <- data$sst_outcome

#data <- import_stn_series('FU2')

#stn_series_fu2  <- data$stn_series
#sst_times_fu2   <- data$sst_times
#sst_outcome_fu2 <- data$sst_outcome

#subs_lost <- data$subs_lost

if (shuffle){
    stn_series[,1] <- sample(stn_series[1:dim(stn_series)[1],1], replace=FALSE)
}
# Out:
# [1] "Successful read of  000051571318_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000051571318.csv"
# [1] "Successful read of  000023358860_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000023358860.csv"
# [1] "Successful read of  000023875871_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000023875871.csv"
# [1] "Successful read of  000020320615_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000020320615.csv"
# [1] "Successful read of  000024477110_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000024477110.csv"
# [1] "Successful read of  000052045472_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000052045472.csv"
# [1] "Successful read of  000015439849_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000015439849.csv"
# [1] "Successful read of  000083236777_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000083236777.csv"
# [1] "Successful read of  000009803741_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000009803741.csv"
# [1] "Successful read of  000023063758_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000023063758.csv"
# [1] "Successful read of  000028982808_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000028982808.csv"
# [1] "Successful read of  000051999613_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000051999613.csv"
# [1] "Successful read of  000078673570_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000078673570.csv"
# [1] "Successful read of  000022084493_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000022084493.csv"
# [1] "Successful read of  000045243088_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000045243088.csv"
# [1] "Successful read of  000069858614_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000069858614.csv"
# [1] "Successful read of  000029580680_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000029580680.csv"
# [1] "Successful read of  000038685366_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000038685366.csv"
# [1] "Successful read of  000075315363_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000075315363.csv"
# [1] "Successful read of  000075578857_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000075578857.csv"
# [1] "Successful read of  000065360091_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000065360091.csv"
# [1] "Successful read of  000027553119_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000027553119.csv"
# [1] "Successful read of  000016590495_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000016590495.csv"
# [1] "Successful read of  000020570622_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000020570622.csv"
# [1] "Successful read of  000041610677_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000041610677.csv"
# [1] "Successful read of  000011310758_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000011310758.csv"
# [1] "Successful read of  000026045785_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000026045785.csv"
# [1] "Successful read of  000090194741_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000090194741.csv"
# [1] "Successful read of  000037045417_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000037045417.csv"
# [1] "Successful read of  000030869248_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000030869248.csv"
# [1] "Successful read of  000083827820_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000083827820.csv"
# [1] "Successful read of  000041224729_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000041224729.csv"
# [1] "Successful read of  000014045403_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000014045403.csv"
# [1] "Successful read of  000071672039_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000071672039.csv"
# [1] "Successful read of  000055417875_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000055417875.csv"
# [1] "Successful read of  000038436183_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000038436183.csv"
# [1] "Successful read of  000025171057_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000025171057.csv"
# [1] "Successful read of  000006260065_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000006260065.csv"
# [1] "Successful read of  000072449671_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000072449671.csv"
# [1] "Successful read of  000032899225_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000032899225.csv"
# [1] "Successful read of  000026470206_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000026470206.csv"
# [1] "Successful read of  000086100102_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000086100102.csv"
# [1] "Successful read of  000058754043_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000058754043.csv"
# [1] "Successful read of  000050271212_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000050271212.csv"
# [1] "Successful read of  000096149560_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000096149560.csv"
# [1] "Successful read of  000012208814_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000012208814.csv"
# [1] "Successful read of  000059564066_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000059564066.csv"
# [1] "Successful read of  000066715400_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_
Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000000642263.csv"
# [1] "Successful read of  000070675464_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000070675464.csv"
# [1] "Successful read of  000002437251_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000002437251.csv"
# [1] "Successful read of  000063366503_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000063366503.csv"
# [1] "Successful read of  000059453804_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000059453804.csv"
# [1] "Successful read of  000054198873_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000054198873.csv"
# [1] "Successful read of  000009736077_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000009736077.csv"
# [1] "Successful read of  000096596623_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000096596623.csv"
# [1] "Successful read of  000043559294_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000043559294.csv"
# [1] "Successful read of  000073691245_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000073691245.csv"
# [1] "Successful read of  000075148743_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000075148743.csv"
# [1] "Successful read of  000053120454_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000053120454.csv"
# [1] "Successful read of  000094989507_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000094989507.csv"
# [1] "Successful read of  000081745414_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000081745414.csv"
# [1] "Successful read of  000065032538_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000065032538.csv"
# [1] "Successful read of  000043804515_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000043804515.csv"
# [1] "Successful read of  000027113512_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000027113512.csv"
# [1] "Successful read of  000092159995_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000092159995.csv"
# [1] "Successful read of  000072824399_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000072824399.csv"
# [1] "Successful read of  000075993279_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000075993279.csv"
# [1] "Successful read of  000020113627_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000020113627.csv"
# [1] "Successful read of  000086975524_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000086975524.csv"
# [1] "Successful read of  000062418041_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000062418041.csv"
# [1] "Successful read of  000033545889_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000033545889.csv"
# [1] "Successful read of  000013424686_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000013424686.csv"
# [1] "Successful read of  000000613223_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000000613223.csv"
# [1] "Successful read of  000068169738_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000068169738.csv"
# [1] "Successful read of  000044211617_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000044211617.csv"
# [1] "Successful read of  000077380027_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000077380027.csv"
# [1] "Successful read of  000020278160_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000020278160.csv"
# [1] "Successful read of  000009407913_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000009407913.csv"
# [1] "Successful read of  000006272781_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000006272781.csv"
# [1] "Successful read of  000041026861_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000041026861.csv"
# [1] "Successful read of  000092548129_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000092548129.csv"
# [1] "Successful read of  000003504454_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000003504454.csv"
# [1] "Successful read of  000061829162_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000061829162.csv"
# [1] "Successful read of  000071765184_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000071765184.csv"
# [1] "Successful read of  000043036636_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000043036636.csv"
# [1] "Successful read of  000056819618_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000056819618.csv"
# [1] "Successful read of  000002660085_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000002660085.csv"
# [1] "Successful read of  000024115048_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000024115048.csv"
# [1] "Successful read of  000055518941_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000055518941.csv"
# [1] "Successful read of  000067661866_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000067661866.csv"
# [1] "Successful read of  000057508486_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000057508486.csv"
# [1] "Successful read of  000015411565_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000015411565.csv"
# [1] "Successful read of  000024436422_Left_preSMA_BL_SSTtimeseries"
# [1] "Successful read of  ss_000024436422.csv"
# [1] "Completed  198 out of 198 STN reads."
# [1] "Completed  198 out of 198 SST reads."
# Attaching package: ‘signal’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, poly

# %% [markdown]
# ### Sanity Check: <br/> Inspect STN Activation and Outcomes ###

# %%
library(ggplot2)
library(reshape2)

options(repr.plot.width=8, repr.plot.height=2)
dmelt <- melt(stn_series[c('TR', 'Subj_1', 'Subj_198')], id.vars = 'TR', variable.name = 'series')
ggplot(dmelt, aes(TR, value)) + geom_line(aes(colour=series))

options(repr.plot.width=8, repr.plot.height=2)
dmelt <- melt(stn_series[c('TR', 'Subj_2', 'Subj_102')], id.vars = 'TR', variable.name = 'series')
ggplot(dmelt, aes(TR, value)) + geom_line(aes(colour=series))

options(repr.plot.width=8, repr.plot.height=2)
dmelt <- melt(stn_series[c('TR', 'Subj_3', 'Subj_58')], id.vars = 'TR', variable.name = 'series')
ggplot(dmelt, aes(TR, value)) + geom_line(aes(colour=series))

options(repr.plot.width=8, repr.plot.height=2)
dmelt <- melt(stn_series[c('TR', 'Subj_4', 'Subj_138')], id.vars = 'TR', variable.name = 'series')
ggplot(dmelt, aes(TR, value)) + geom_line(aes(colour=series))


labels <- c("GO_SUCCESS", "GO_FAILURE", 'STOP_SUCCESS', 'STOP_FAILURE', 'GO_TOO_LATE', 'GO_WRONG_KEY_RESPONSE', 'STOP_TOO_EARLY_RESPONSE')

dmelt <- melt(data.frame('Outcome' = sst_outcome[,1], 'Time' = sst_times[,1]/1000/2.2), id.vars = 'Time', variable.name = 'series', na.rm=TRUE)
ggplot(dmelt, aes(Time, value)) + geom_point(colour='red') + scale_y_continuous('outcome', breaks=seq(1,7,1), labels=labels, c(1,7))

dmelt <- melt(data.frame('Outcome' = sst_outcome[,194], 'Time' = sst_times[,194]/1000/2.2), id.vars = 'Time', variable.name = 'series', na.rm=TRUE)
ggplot(dmelt, aes(Time, value)) + geom_point(colour='dark cyan') + scale_y_continuous('outcome', breaks=seq(1,7,1), labels=labels, c(1,7))
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ## Fit GLM to STN Activity ##
#
# For each participant:
# - Remove non-existent conditions from outcome set
# - Determine onset times (in TRs)
# - Set event durations (event-based --> 0s)
# - Create expected activation timeseries via HRF - regressor convolution
# - Create design matrix with second order polynomial drift
# - Fit the model to the data

# %%
source('get_stn_betas.r')

# --------------------------------------------#
#           THIS CAN TAKE A WHILE!!           #
# --------------------------------------------#
n_fit <- 198
if (use_cached) {
    lm_list <- readRDS(paste('lm_list_198_',fuc,'_',roi,'_',subset,'.rds',sep=''))
} else {
    #clumping <- list(c(1,2,5,6), c(3,4))
    clumping <- list(c(1), c(2), c(3), c(4), c(5), c(6), c(7))
    lm_list  <- get_stn_betas(stn_series, sst_times, sst_outcome, n_fit, clumping, labels)
}
# Out:
# [1] "Subject 1 GO_SUCCESS beta: 4.23. Sig: FALSE STOP_SUCCESS beta: -0.19. Sig: FALSE"
# [1] "Subject 2 GO_SUCCESS beta: 6.6. Sig: TRUE STOP_SUCCESS beta: 0.41. Sig: FALSE"
# [1] "Subject 3 GO_SUCCESS beta: 4.96. Sig: FALSE STOP_SUCCESS beta: 15.04. Sig: TRUE"
# [1] "Subject 4 GO_SUCCESS beta: 3.39. Sig: FALSE STOP_SUCCESS beta: -0.45. Sig: FALSE"
# [1] "Subject 5 GO_SUCCESS beta: 2.67. Sig: FALSE STOP_SUCCESS beta: 0.43. Sig: FALSE"
# [1] "Subject 6 GO_SUCCESS beta: 7.37. Sig: TRUE STOP_SUCCESS beta: 8.47. Sig: FALSE"
# [1] "Subject 7 GO_SUCCESS beta: 3.69. Sig: FALSE STOP_SUCCESS beta: 5.07. Sig: FALSE"
# [1] "Subject 8 GO_SUCCESS beta: 3.4. Sig: FALSE STOP_SUCCESS beta: 8.21. Sig: FALSE"
# [1] "Subject 181 GO_SUCCESS beta: 4.66. Sig: FALSE STOP_SUCCESS beta: 5.7. Sig: FALSE"
# [1] "Subject 182 GO_SUCCESS beta: 1.62. Sig: FALSE STOP_SUCCESS beta: 9.72. Sig: FALSE"
# [1] "Subject 183 GO_SUCCESS beta: 4.5. Sig: FALSE STOP_SUCCESS beta: 5.92. Sig: FALSE"
# [1] "Subject 184 GO_SUCCESS beta: 3.67. Sig: FALSE STOP_SUCCESS beta: 10.97. Sig: TRUE"
# [1] "Subject 185 GO_SUCCESS beta: 6.03. Sig: TRUE STOP_SUCCESS beta: -3.79. Sig: FALSE"
# [1] "Subject 186 GO_SUCCESS beta: 5.16. Sig: FALSE STOP_SUCCESS beta: 12.5. Sig: TRUE"
# [1] "Subject 187 GO_SUCCESS beta: 4.56. Sig: FALSE STOP_SUCCESS beta: 0.47. Sig: FALSE"
# [1] "Subject 188 GO_SUCCESS beta: 4.47. Sig: FALSE STOP_SUCCESS beta: 9.71. Sig: FALSE"
# [1] "Subject 189 GO_SUCCESS beta: 3.32. Sig: FALSE STOP_SUCCESS beta: 8.8. Sig: FALSE"
# [1] "Subject 190 GO_SUCCESS beta: 5.01. Sig: FALSE STOP_SUCCESS beta: 5.51. Sig: FALSE"
# [1] "Subject 191 GO_SUCCESS beta: 3.73. Sig: FALSE STOP_SUCCESS beta: 5.55. Sig: FALSE"
# [1] "Subject 192 GO_SUCCESS beta: 4.58. Sig: FALSE STOP_SUCCESS beta: 5.68. Sig: FALSE"
# [1] "Subject 193 GO_SUCCESS beta: 5.38. Sig: FALSE STOP_SUCCESS beta: 2.73. Sig: FALSE"
# [1] "Subject 194 GO_SUCCESS beta: 3.63. Sig: FALSE STOP_SUCCESS beta: 10.63. Sig: TRUE"
# [1] "Subject 195 GO_SUCCESS beta: 4.42. Sig: FALSE STOP_SUCCESS beta: -0.37. Sig: FALSE"
# [1] "Subject 196 GO_SUCCESS beta: 6.66. Sig: TRUE STOP_SUCCESS beta: 5.37. Sig: FALSE"
# [1] "Subject 197 GO_SUCCESS beta: 3.11. Sig: FALSE STOP_SUCCESS beta: 4.93. Sig: FALSE"
# [1] "Subject 198 GO_SUCCESS beta: 4.97. Sig: FALSE STOP_SUCCESS beta: -3.18. Sig: FALSE"
# [1] ""
# [1] "Fraction of GO_SUCCESS   betas which are significant: 0.0757575757575758"
# [1] "Fraction of STOP_SUCCESS betas which are significant: 0.141414141414141"

# %%
if (save) {
    saveRDS(lm_list,paste('lm_list_198_',fuc,'_',roi,'_',subset,'.rds',sep=''))
}

# %% [markdown]
# ### Plot Beta Values ###

# %%
if (use_cached) {
    contrasts <- readRDS(contrasts, paste('contrasts_198_',fuc,'_',roi,'_',subset,'.rds',sep=''))
    betas <- readRDS(betas, paste('betas_198_',fuc,'_',roi,'_',subset,'.rds',sep=''))  
} else {
    n_cols <- 4
    betas     <- array(dim=c(n_fit,n_cols))
    contrasts <- array(dim=c(n_fit,1))

    cols <- c('design_matGO_SUCCESS','design_matSTOP_SUCCESS','design_matSTOP_FAILURE','design_matGO_TOO_LATE')#,'design_matGO_WRONG_KEY_RESPONSE','design_matSTOP_TOO_EARLY_RESPONSE')
    cols <- cols[1:n_cols]
    print(cols)
    for (subj_num in 1:n_fit) {
        betas[subj_num,1:n_cols] <- lm_list[[subj_num]]$lm$coefficients[cols]

        # Contrast go conds with stop conds ignoring 'failures'
        contr <- as.vector(c(-1, 1, 0, 0))
        contrasts[subj_num,1] <- contr %*% as.vector(betas[subj_num,c(1:n_cols)])
    }
    betas <- data.frame(betas)
    colnames(betas) <- c('GO_SUCCESS','STOP_SUCCESS','STOP_FAILURE','GO_TOO_LATE') #,'GO_WRONG_KEY_RESPONSE','STOP_TOO_EARLY_RESPONSE')
}

if (save) {
    saveRDS(contrasts, paste('contrasts_198_',fuc,'_',roi,'_',subset,'.rds',sep=''))
    saveRDS(betas, paste('betas_198_',fuc,'_',roi,'_',subset,'.rds',sep=''))
}

options(repr.plot.width=8, repr.plot.height=2)
ggplot(melt(data.frame(contrasts=contrasts), id.vars=NULL), aes(x=value)) + geom_histogram(bins=50)

options(repr.plot.width=8, repr.plot.height=3)
#ggplot(melt(data.frame(betas_go=betas[,1], betas_stop=betas[,2], betas_stop_fail=betas[,3], betas_go_late=betas[,4]), id.vars=NULL), aes(x=value)) + facet_wrap(~variable, scales = "free") + geom_histogram(bins=50)
ggplot(melt(data.frame(betas_go=betas[,1], betas_stop=betas[,2]), id.vars=NULL), aes(x=value)) + facet_wrap(~variable, scales = "free") + geom_histogram(bins=50)

#t.test(x = betas[,2], y = betas[,1], alternative='greater')
t.test(x = contrasts, alternative='greater')
# Out:
# [1] "design_matGO_SUCCESS"   "design_matSTOP_SUCCESS" "design_matSTOP_FAILURE"
# [4] "design_matGO_TOO_LATE"
# Warning message:
# “Removed 55 rows containing non-finite values (stat_bin).”
# plot without title
# 	One Sample t-test
#
# data:  contrasts
# t = -0.48314, df = 142, p-value = 0.6851
# alternative hypothesis: true mean is greater than 0
# 95 percent confidence interval:
#  -0.9901941        Inf
# sample estimates:
#  mean of x
# -0.2236789
# plot without title

# %%
options(repr.plot.width=6, repr.plot.height=3)

dmelt <- melt(betas[c('STOP_SUCCESS', 'STOP_FAILURE')], id.vars = 'STOP_SUCCESS', na.rm=TRUE)
ggplot(dmelt, aes(STOP_SUCCESS, value)) + geom_point(colour='dark cyan') + scale_y_continuous('Stop Failure Beta') + scale_x_continuous('Stop Success Beta') + theme(aspect.ratio = 0.7)

dmelt <- melt(betas[c('GO_SUCCESS', 'STOP_SUCCESS')], id.vars = 'GO_SUCCESS', na.rm=TRUE)
ggplot(dmelt, aes(GO_SUCCESS, value)) + geom_point(colour='dark cyan') + scale_x_continuous('GO Success Beta') + scale_y_continuous('Stop Success Beta') + theme(aspect.ratio = 0.7)

dmelt <- melt(betas[c('GO_SUCCESS', 'STOP_FAILURE')], id.vars = 'GO_SUCCESS', na.rm=TRUE)
ggplot(dmelt, aes(GO_SUCCESS, value)) + geom_point(colour='dark cyan') + scale_x_continuous('Go Success Beta') + scale_y_continuous('Stop Failure Beta') + theme(aspect.ratio = 0.7)
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ### Sanity Check <br/> Raw Regressors and Design Matrix###

# %%
conv_reg.m <- melt(lm_list[[1]]$conv_regs, id.vars = 'TR')

options(repr.plot.width=6, repr.plot.height=5)

p <- ggplot(conv_reg.m, aes(variable, TR)) +
      geom_tile(aes(fill = value)) + 
      scale_fill_gradient(low = "white", high = "steelblue") + 
      labs(x = "") + scale_x_discrete(expand = c(0, 0)) + #scale_y_discrete(expand = c(0, 0)) +
      theme(panel.grid.major = element_blank(),panel.grid.minor = element_blank(),
              panel.background = element_blank(),
              legend.position = "none",
              axis.ticks = element_blank(),
              axis.text.x = element_text(angle = 330, hjust = 0, colour = "grey50"))

print(p)

##### DESIGN MATRIX w/ DRIFTS
dmatdf <- data.frame(design_mat)
colnames(dmatdf) <- c(labels[setdiff(1:7, bad_cond)], 'Intercept', 'Linear Drift', 'Sq. Drift')
dmatdf['TR'] <- 1:444

dmatdf.m <- melt(dmatdf, id.vars = 'TR')
#dmatdf.m <- ddply(dmatdf.m, .(variable), transform, rescale = scale(value))

#options(repr.plot.width=6, repr.plot.height=5)

#p <- ggplot(dmatdf.m, aes(variable, TR)) +
#      geom_tile(aes(fill = value)) + 
#      scale_fill_gradient(low = "white", high = "steelblue") + 
#      labs(x = "") + scale_x_discrete(expand = c(0, 0)) + #scale_y_discrete(expand = c(0, 0)) +
#      theme(panel.grid.major = element_blank(),panel.grid.minor = element_blank(),
#              panel.background = element_blank(),
#              legend.position = "none",
#              axis.ticks = element_blank(),
#              axis.text.x = element_text(size = base_size * 0.8, angle = 330, hjust = 0, colour = "grey50"))

#print(p)
# Out:
# plot without title

# %%
source('fir.r') 
library('corpcor')
#lm_list[[1]]$onsets

onsets    <- lm_list[[1]]$onsets[[1]]
durations <- integer(length(onsets))

activations <- stn_series[,1]
n_scans <- 444
n_conds <- 1
n_voxels <- 1
TR <- 1
    
# Scale parameter - sets resolution
scale <- 10

# Rescale onsets
onsets    <- onsets    * scale
durations <- durations * scale

n_scans <- n_scans * scale
res     <- TR / scale
stims   <- rep(0, ceiling(n_scans))

## ESTIMATE HRF USING FIR BASIS SET

# CREATE FIR DESIGN MATRIX
# WE ASSUME HRF IS 16 TRS LONG
hrf_len <- 8
 
# BASIS SET FOR EACH CONDITOIN IS A TRAIN OF INPULSES
fir_bases <- matrix(0, n_scans, hrf_len*n_conds)
 
for (cond in 1:n_conds) {
    col_subset <- ((cond - 1)* hrf_len + 1):(cond*hrf_len)
    
    #for (onset in 1:length(onsets[[cond]]) ) {
    for (onset in 1:length(onsets) ) {
        #impulse_times <- onsets(onset):onsets(onset) + hrf_len - 1;
        impulse_times <- seq(onsets[onset], onsets[onset] + hrf_len*scale - 1, scale)
        
        for (impulse in 1:length(impulse_times)) {
            fir_bases[impulse_times[impulse], col_subset[impulse]] <- 1;
        }
    }
}

options(repr.plot.width=6, repr.plot.height=2)

acts <- matrix(0, length(activations)*scale, 1)
acts[1,1] <- activations[1]
for (i in 1:(length(activations)-1)) {
    acts[ ((i-1)*(scale)+1):(i*(scale)), 1] <- as.matrix(approx(c(1,11), c(activations[i], activations[i+1]), n=11)$y[1:10])
}

# ESTIMATE HRF FOR EACH CONDITION AND VOXEL
fir_hrf_est <- pseudoinverse( t(fir_bases) %*% fir_bases) %*% (t(fir_bases) %*% acts)

# RESHAPE HRFS
#hHatFIR <- reshape(fir_hrf_est, hrf_len, n_conds, n_voxels)

ggplot(melt(data.frame(TR=1:hrf_len, hrf=fir_hrf_est), id.vars='TR'), aes(TR,value)) + geom_point()
# Out:
# plot without title

# %%
plot_avg_hrf <- function(sst_times, subj_num, cond, roi_series, look_ahead, color) {

    # Masks for getting trial times
    big_cond_msk <- apply(sst_outcome, c(1,2), function(x) x %in% cond)
    cond_msk     <- big_cond_msk[,subj_num]

    # If this condition doesn't occur, skip it.
    if (sum(cond_msk) == 0) {
        bad_cond <- cbind(bad_cond,cond)
        next
    }

    # For some reason fmri.stimulus can't handle the zero.
    # Only one of thousands of pts, so just 'fix' it.
    if (sst_times[cond_msk,subj_num][1] == 0) {
        sst_times[cond_msk,subj_num][1] <- 500
    }

    # Trial onset times and their durations - 0s for event design
    onsets    <- sst_times[cond_msk, subj_num]
    onsets    <- as.vector(na.omit(onsets/1000/2.2))
    durations <- double(length(onsets))

    #print(onsets)
        
    # Get convolved regressor for condition
    #conv_regs[,cond] <- fmri.stimulus(scans = n_scans, onsets = onsets, duration = durations)

    n_ons <- length(onsets)
    blah  <- array(dim=c(n_ons,look_ahead+1))
    for (i in 1:n_ons) {
        blah[i,1] <- ceiling(onsets[i]) - onsets[i]
        for (j in 1:look_ahead) {
            blah[i,j + 1] <- roi_series[ceiling(onsets[i]) + j - 1]
        }
    }

    blah_2 <- array(dim=c(n_ons*look_ahead,2))
    j <- 0
    for (i in 1:n_ons){
        blah_2[j + 1:look_ahead, 1] <- blah[i, 1] + 0:(look_ahead-1)
        blah_2[j + 1:look_ahead, 2] <- blah[i, 2:(look_ahead+1)]
        j <- j + look_ahead
    }

    blah_3 <- data.frame('Times' = blah_2[,1], 'Activation' = blah_2[,2])
    plt <- ggplot(melt(blah_3, id.vars = 'Times'), aes(Times,value)) + geom_point(colour=color)
    print(plt)
    
    blah_3_sorted <- blah_3[order(blah_3['Times']),]

    library(signal)
    bf <- butter(2, 1/800, type="low")
    b1 <- filtfilt(bf, blah_3_sorted[['Activation']])

    df <- data.frame('Times' = blah_3_sorted[,1], 'Activation' = b1)
    plt <- ggplot(melt(df, id.vars = 'Times'), aes(Times,value)) + geom_point(colour=color)
    print(plt)
    
}

subj <- 10
cond <- 1
look_ahead <- 9
                          
options(repr.plot.width=7, repr.plot.height=2)

plot_avg_hrf(sst_times, subj, cond, lm_list[[subj]]$conv_regs[,cond],look_ahead, 'red')
plot_avg_hrf(sst_times, subj,cond, stn_series[,subj],look_ahead, 'dark cyan')

len <- length(stn_series[,subj])
rand <- sample(stn_series[,subj], size=len, replace=FALSE)
plot_avg_hrf(sst_times, subj,cond, rand,look_ahead, 'dark green')
# Out:
# Error in apply(sst_outcome, c(1, 2), function(x) x %in% cond): object 'sst_outcome' not found
# Traceback:
#
# 1. plot_avg_hrf(sst_times, subj, cond, lm_list[[subj]]$conv_regs[,
#  .     cond], look_ahead, "red")
# 2. apply(sst_outcome, c(1, 2), function(x) x %in% cond)   # at line 4 of file <text>
